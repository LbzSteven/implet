# %%
# %load_ext autoreload
# %autoreload 3
import numpy as np
import utils
import warnings
import torch
import pickle
import matplotlib.pyplot as plt
from utils.constants import xai_names
from utils.visualization import plot_multiple_images_with_attribution
from utils.shapelet import get_distances_info_gain
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
device = 'cuda' if torch.cuda.is_available else 'cpu'

# %%
from tsai.models.FCN import FCN
model_path = 'models/GunPoint/'
model = FCN(c_in=1, c_out=2)
state_dict = torch.load(f'{model_path}/weight.pt',map_location='cuda:1')
model.load_state_dict(state_dict)
model.eval()

train_x, test_x, train_y, test_y, enc1 = utils.read_UCR_UEA('GunPoint', None)

test_y = np.argmax(test_y, axis=1)
train_y = np.argmax(train_y, axis=1)
preds = np.load(f'{model_path}/test_preds.npy')

# %%
attr.keys()
# Out:
# dict_keys(['target_class', 'xai_name', 'attributions', 'attribution_shapelet'])

# %%
for xai_name in xai_names:

    # attr_gp, _= get_gt_attr(model,test_gp,None,None,
    #                         save_dir=f'attributions/GunPoint/{xai_name}',
    #                         xai_name=xai_name,target_class=None)
    print(xai_name)

    with open(f'attributions/GunPoint/{xai_name}/train_exp.pkl', 'rb') as f:
        attr = pickle.load(f)
    attr_gp = attr['attributions']
    plot_multiple_images_with_attribution(test_x[np.where(test_y==0)], preds[np.where(test_y==0)], 2, (1, 2), (12, 3), 
                                          use_attribution=True,
                                          attributions=attr_gp[np.where(test_y==0)],
                                          normalize_attribution=True,
                                          save_path=None,
                                          test_y = test_y[np.where(test_y==0)],
                                         )
    plot_multiple_images_with_attribution(test_x[np.where(test_y==1)], preds[np.where(test_y==1)], 2, (1, 2), (12, 3), 
                                          use_attribution=True,
                                          attributions=attr_gp[np.where(test_y==1)],
                                          normalize_attribution=True,
                                          save_path=None,
                                          test_y = test_y[np.where(test_y==1)],
                                         )
# Out:
# DeepLift
# IntegratedGradients
# InputXGradient
# Saliency
# Lime
# Occlusion
# KernelShap
# GuidedBackprop

# %%
with open('attributions/GunPoint/DeepLift/train_exp.pkl', 'rb') as f:
    attr = pickle.load(f)
attr_gp = attr['attributions']

# %%
plt.plot(np.abs(attr_gp[0]))
plt.axvline(x=30, color='r', linestyle='--', linewidth=2)
plt.axvline(x=55, color='r', linestyle='--', linewidth=2)

# %%
plt.plot(test_x[0].flatten(),label=f'instance{0} class {test_y[0]}')
plt.plot(np.arange(30,55),test_x[0,:,30:55].flatten(),
         linewidth=5,label='shapelet')
plt.legend()
# plt.plot(test_x[0,:,30:55].flatten())

# %%
shapelet = test_x[0,:,30:55].flatten()

shapelet_distances_train, info_gain, best_threshold = get_distances_info_gain(dataset=train_x, shapelet=shapelet, length=25, pos=30, labels=train_y)
print(info_gain)
# Out:
# 0.38569351768442706

# %%
shapelet_distances_test, info_gain, best_threshold = get_distances_info_gain(dataset=test_x, shapelet=shapelet, length=25, pos=30, labels=test_y)
print(info_gain)
# Out:
# 0.38818428032332775

# %%
from sklearn.metrics import (
    accuracy_score,
)
from sklearn.linear_model import LinearRegression

# %%
shapelet_distances_train = shapelet_distances_train.reshape(-1, 1)
shapelet_distances_test = shapelet_distances_test.reshape(-1, 1)

classifier = LinearRegression()
classifier.fit(shapelet_distances_train, train_y)
train_pred = classifier.predict(shapelet_distances_train)
train_pred[train_pred < 0.5] = 0
train_pred[train_pred >= 0.5] = 1

test_pred = classifier.predict(shapelet_distances_test)
test_pred[test_pred < 0.5] = 0
test_pred[test_pred >= 0.5] = 1

print(f'Training Accuracy = {accuracy_score(train_y, train_pred):.2f}')
print(f'Testing Accuracy = {accuracy_score(test_y, test_pred):.2f}')
# Out:
# Training Accuracy = 0.82
# Testing Accuracy = 0.81
